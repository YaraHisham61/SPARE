# %%
import matplotlib.pyplot as plt
from scripts.data_visualization import load_sample, overlay_boxes
autoreload = True

IMG_NAME = "sa_11177068"

# %%
img,meta = load_sample(IMG_NAME)

result = overlay_boxes(img, [ann['bbox'] for ann in meta["annotations"]], color=(255, 0, 0))

# %%
plt.imshow(result)
plt.axis("off")
plt.show()
